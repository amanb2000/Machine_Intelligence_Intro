# %% [markdown]
# # ECE324: Assignment 2, Part I
#
# ## Hyperparameters
#
# - Activation function $\in$ {sigmoid, ReLU, Linear}.
# - Learning rate `alpha`.
# - Number of `epochs`.
# - Random seed `rng`.
#
# ## Steps
#
# - [x] Import `traindata.csv`, `trainlabel.csv`, `validdata.csv`, and `validlabel.csv` via `np.loadtxt()`.
# - [x] Code the neural network function `Neuron` that takes in {input $I$}.
#     - [x] Initialize weights to random values between 0 and 1.
#     - [x] Internal parameters: `alpha`, `activation function` (callable object with two functions: `activate` (default __call__) and `grad` to produce gradient), `weights`, and `bias`.
#     - [x] `grad_desc` funciton that takes in a full epoch of data and computes average $\frac{\partial \text{loss}}{\partial w_i}$ for each $w_i$ and bias $b$ -> adjusts parameters using $\alpha$.
# - [x] Code a `mean_squared_error` function that takes in neuron output `Y` and compares it with true label `L` and calculates $(I-L)^2$.
# - [x] Meta-function to run a training trial with the specified hyperparameters {$\alpha$, `epochs`, `activation`, `random seed`} and output the following values for each epoch:
#     - [x] Training loss.
#     - [x] Validation loss.
#     - [x] Training accuracy.
#     - [x] Validation accuracy.
# - [x] Function to 'properly plot' the T+V loss vs. epoch on one graph.
# - [x] Function to 'properly plot' the T+V accuracy vs. epoch on one graph.

# %%
##############
# IMPORT BOX #
##############

import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd

from dispkernel import *

# %%
###################
# DATA IMPORT BOX #
###################

train_X = np.loadtxt('traindata.csv', delimiter=',')
train_Y = np.loadtxt('trainlabel.csv', delimiter=',')
valid_X = np.loadtxt('validdata.csv', delimiter=',')
valid_Y = np.loadtxt('validlabel.csv', delimiter=',')

print("=== Validating Data ===")
print("Dimensions of training X: \t{}".format(train_X.shape))
print("Dimensions of training Y: \t{}".format(train_Y.shape))
print("")
print("Dimensions of validation X: \t{}".format(valid_X.shape))
print("Dimensions of validation Y: \t{}".format(valid_Y.shape))
# Out:
# === Validating Data ===
# Dimensions of training X: 	(200, 9)
# Dimensions of training Y: 	(200,)
#
# Dimensions of validation X: 	(20, 9)
# Dimensions of validation Y: 	(20,)

# %%
class Neuron(object):
    def __init__(self, num_inputs, activ_func, rand_seed=0, alpha=0.01):
        self.rand_seed = rand_seed
        np.random.seed(rand_seed)
        self.weights = np.random.random(num_inputs)
        self.bias = np.random.random()
        self.activ_func = activ_func
        self.alpha = alpha

    def Z(self, inp):
        return inp.dot(self.weights) + self.bias
    
    def __call__(self, inp):
        return self.activ_func(inp.dot(self.weights) + self.bias)

    def train(self, X_train, Y_train, X_valid, Y_valid, num_epochs):
        train_loss_v_epoch = []
        valid_loss_v_epoch = []

        train_accuracy_v_epoch = []
        valid_accuracy_v_epoch = []


        for e in range(num_epochs):
            train_loss = self.grad_desc(X_train, Y_train)
            train_loss_v_epoch.append(train_loss)

            valid_loss = self.mean_loss(X_valid, Y_valid)
            valid_loss_v_epoch.append(valid_loss)

            train_acc = self.get_accuracy(X_train, Y_train)
            train_accuracy_v_epoch.append(train_acc)

            valid_acc = self.get_accuracy(X_valid, Y_valid)
            valid_accuracy_v_epoch.append(valid_acc)

        return train_loss_v_epoch, valid_loss_v_epoch, train_accuracy_v_epoch, valid_accuracy_v_epoch

    
    def grad_desc(self, X, Y):
        """
        Function to perform one step of gradient descent on an epoch of data.

        1. Calculate $\frac{\partial \text{loss} }{\partial \text{parameter} }$ for each parameter w_i and b.
            a. d loss_j / d Y[j]
            b. d Y[j] / d Z[j] where Z[j] is the unactivated output of the neuron.
            c. d Z[j] / d w_i = X[j][i]; d Z[j] / d b = 1

            Multiply a*b*c to get d loss_j / d param_i
        2. Calculate the average gradient for each parameter.
        3. Apply the update rule to each parameter.
        4. Return (average_loss, training_accuracy, validation_accuracy)
        """

        # Instantiating Gradients, Loss
        weight_grads = np.zeros(self.weights.size)
        bias_grad = 0
        avg_loss = 0

        # Iterating through each training example to calculate gradients for parameters (and avg loss)
        for j in range(len(Y)):
            pred = self(X[j])
            loss = (pred - Y[j])**2

            # Solving for components to put into chain rule
            dldy = 2*(pred - Y[j])
            dydz = self.activ_func.grad(self.Z(X[j]))
            dzdw = np.copy(X[j])

            # Updating averages via back propagation (chain rule)
            weight_grads += (dldy*dydz*dzdw)/len(Y)
            bias_grad += (dldy*dydz*1)/len(Y)
            avg_loss += loss/len(Y)

        # Updating parameters based on gradients and learning rate

        self.weights -= weight_grads*self.alpha
        self.bias -= bias_grad*self.alpha

        return avg_loss

    def mean_loss(self, X, Y):
        pred = self(X)
        sq_diff = (pred - Y)**2
        return np.mean(sq_diff)
    
    def get_accuracy(self, X, Y):
        """
        Function to get the accuracy of the model for predicting values of Y based on X.
        """
        one_if_diff = np.abs(np.round(self(X)) - Y)
        num_incorrect = sum(one_if_diff)
        accuracy = (len(Y)-num_incorrect)/len(Y)
        return accuracy

# %%
# Various activation functions, implemented as callable objects with auxillary 'gradient' (grad) functions.

class linear_activation(object):
    def __init__(self):
        self.name = 'Linear'
        return
    
    def __call__(self, inp):
        """
        Input is a scalar. We apply a linear activation function by returning the initial value.
        """

        return inp 
    
    def grad(self, inp):
        """
        Linear activation function has $y = x$ -> $dy/dx = 1$
        """
        return 1

class sigmoid_activation(object):
    def __init__(self):
        self.name = 'Sigmoid'
        return
    
    def __call__(self, inp):
        """
        Input is a scalar. We apply a linear activation function by returning the initial value.
        """

        return 1/(1+np.exp(-inp)) 
    
    def grad(self, inp):
        """
        Linear activation function has $y = x$ -> $dy/dx = 1$
        """
        return self(inp)*(1-self(inp))
        
class ReLU_activation(object):
    def __init__(self):
        self.name = 'ReLU'
        return
    
    def __call__(self, inp):
        """
        Input is a scalar. We apply a linear activation function by returning the initial value.
        """

        return np.where(inp >= 0, inp, 0*inp)
    
    def grad(self, inp):
        """
        Linear activation function has $y = x$ -> $dy/dx = 1$
        """
        return np.heaviside(inp, 1)
        

linear = linear_activation()
sigmoid = sigmoid_activation()
ReLU = ReLU_activation()

# %%
def plot_report(train_loss_v_epoch, valid_loss_v_epoch, train_accuracy_v_epoch, valid_accuracy_v_epoch):
    plt.plot(train_loss_v_epoch)
    plt.plot(valid_loss_v_epoch)
    plt.title('Training and Validation Loss Curves')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Loss')
    plt.legend(['train', 'validation'])
    plt.show()

    plt.plot(train_accuracy_v_epoch)
    plt.plot(valid_accuracy_v_epoch)
    plt.title('Training and Validation Accuracy Curves')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['train', 'validation'])
    plt.show()

# %%
def get_report(activation_func, num_epochs=200, alpha=0.01, rand_seed=0, plot=True, mute=False):
    NN = Neuron(len(train_X[0]), activation_func, alpha=alpha, rand_seed=rand_seed)

    train_loss_v_epoch, valid_loss_v_epoch, train_accuracy_v_epoch, valid_accuracy_v_epoch = NN.train(train_X, train_Y, valid_X, valid_Y, num_epochs)

    if not mute:
        print("Activation Function: \t{}".format(NN.activ_func.name))
        print("Learning Rate: \t\t{}".format(NN.alpha))
        print("Number of Epochs: \t{}".format(num_epochs))
        print("Random Seed: \t\t{}".format(NN.rand_seed))

        print('=================================')
        print("Final Training Accuracy: \t{}".format(train_accuracy_v_epoch[-1]))
        print("Final Validation Accuracy: \t{}".format(valid_accuracy_v_epoch[-1]))
        print("Final Training Loss (avg): \t{}".format(train_loss_v_epoch[-1]))
        print("Final Validation Loss (avg): \t{}".format(valid_loss_v_epoch[-1]))

    if plot:
        plot_report(train_loss_v_epoch, valid_loss_v_epoch, train_accuracy_v_epoch, valid_accuracy_v_epoch)

        print("\n\n")

    return {
        'model': NN,
        'training loss': train_loss_v_epoch,
        'validation loss': valid_loss_v_epoch,
        'training accuracy': train_accuracy_v_epoch,
        'validation accuracy': valid_accuracy_v_epoch,
        'final validation accuracy': valid_accuracy_v_epoch[-1],
        'final validation loss': valid_loss_v_epoch[-1],
        'final training accuracy': train_accuracy_v_epoch[-1],
        'final training loss': train_loss_v_epoch[-1] 
    }

# %%
"""
=== TESTING THE META FUNCTIONS ===

Recall: 
    linear      = linear_activation()
    sigmoid     = sigmoid_activation()
    ReLU        = ReLU_activation()
"""

NN = get_report(linear, num_epochs=200, alpha=0.01, rand_seed=0, plot=False)

get_report(sigmoid, num_epochs=200, alpha=0.1, rand_seed=99, plot=False)

get_report(ReLU, num_epochs=200, alpha=0.01, rand_seed=99, plot=False)
# Out:
# Activation Function: 	Linear
# Learning Rate: 		0.01
# Number of Epochs: 	200
# Random Seed: 		0
# ...
# Final Training Accuracy: 	0.925
# Final Validation Accuracy: 	0.9
# Final Training Loss (avg): 	0.09237465293882255
# Final Validation Loss (avg): 	0.11021731861570201
# Activation Function: 	Sigmoid
# Learning Rate: 		0.1
# Number of Epochs: 	200
# Random Seed: 		99
# ...
# Final Training Accuracy: 	0.975
# Final Validation Accuracy: 	1.0
# Final Training Loss (avg): 	0.07862877483019323
# Final Validation Loss (avg): 	0.0863168837809235
# Activation Function: 	ReLU
# Learning Rate: 		0.01
# Number of Epochs: 	200
# Random Seed: 		99
# ...
# Final Training Accuracy: 	0.95
# Final Validation Accuracy: 	0.95
# Final Training Loss (avg): 	0.04323016799789989
# Final Validation Loss (avg): 	0.05288064579543892
# {'model': <__main__.Neuron at 0x11db99d60>,
#  'training loss': [6.743255556816783,
#   5.765311932063536,
#   4.933503194874371,
#   4.225933859386932,
#   3.6240145099351824,
# ...

# %%
"""
=== PART 6.1.1: Effect of the Number of Epochs ===

REQUESTED:
* "Tabular form" for data that shows the effect of hyperparameters on accuracy.
* Hyper parameter: NUMBER OF EPOCHS
* Must "select and report reasonable values for other parameters.

EXECUTION: 
* We select values of `num_epochs` = [1, 5, 10, 100, 250, 500, 1000, 2000]
* Reasonable other values:
    * alpha:            0.05
    * active. func.:    ReLU
    * random seed:      120
"""

alpha = 0.05
epochs = [1, 5, 10, 100, 250, 500, 1000, 2000]
random_seed = 120

# Storing 'effects on training and validation accuracy'.
training_accuracies = []
validation_accuracies = []

for e in epochs:
    report = get_report(ReLU, num_epochs=e, alpha=alpha, rand_seed=random_seed, plot=False, mute=True)

    training_accuracies.append(report['final training accuracy'])
    validation_accuracies.append(report['final validation accuracy'])

print("=== EFFECT OF NUMBER OF EPOCHS ON TRAINING AND VALIDATION ACCURACY ===")
# print("Epochs: \t\t{}".format(epochs))
# print("Training Accuracies: \t{}".format(training_accuracies))
# print("Validation Accuracies: \t{}".format(validation_accuracies))

d = {'Epoch': epochs, 'Train Acc': training_accuracies, 'Valid Acc': validation_accuracies}
df = pd.DataFrame(data=d)
df
# Out:
# === EFFECT OF NUMBER OF EPOCHS ON TRAINING AND VALIDATION ACCURACY ===
#    Epoch  Train Acc  Valid Acc
# 0      1     -0.825      -0.85
# 1      5      0.205       0.10
# 2     10      0.375       0.35
# 3    100      0.975       1.00
# 4    250      0.985       1.00
# 5    500      0.985       1.00
# 6   1000      0.990       1.00
# 7   2000      1.000       1.00

# %%
"""
=== PART 6.1.2: Effect of Learning Rate ===

REQUESTED:
* "Tabular form" for data that shows the effect of hyperparameters on accuracy.
* Hyper parameter: ALPHA
* Must "select and report reasonable values for other parameters.

EXECUTION: 
* We select values of `alpha` = [.0001, .001, .01, .02, .05, .1, .25, .5, 1, 2]
* Reasonable other values:
    * epochs:           250
    * active. func.:    ReLU
    * random seed:      160
"""

epochs = 250
alphas = [.0001, .001, .01, .02, .05, .1, .25, .5, 1, 2, 10, 20, 50, 100, 250, 500]
random_seed = 160

# Storing 'effects on training and validation accuracy'.
training_accuracies = []
validation_accuracies = []

for alpha in alphas:
    report = get_report(ReLU, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=False, mute=True)

    training_accuracies.append(report['final training accuracy'])
    validation_accuracies.append(report['final validation accuracy'])

print("=== EFFECT OF LEARNING RATE ON TRAINING AND VALIDATION ACCURACY ===")
# print("Alphas: \t\t{}".format(alphas))
# print("Training Accuracies: \t{}".format(training_accuracies))
# print("Validation Accuracies: \t{}".format(validation_accuracies))

d = {'LR': alphas, 'Train Acc': training_accuracies, 'Valid Acc': validation_accuracies}
df = pd.DataFrame(data=d)
df
# Out:
# === EFFECT OF LEARNING RATE ON TRAINING AND VALIDATION ACCURACY ===
#           LR  Train Acc  Valid Acc
# 0     0.0001     -1.235      -1.15
# 1     0.0010      0.495       0.55
# 2     0.0100      0.960       0.95
# 3     0.0200      0.980       0.95
# 4     0.0500      0.985       0.95
# 5     0.1000      0.990       1.00
# 6     0.2500      0.665       0.65
# 7     0.5000      0.665       0.65
# 8     1.0000      0.665       0.65
# 9     2.0000      0.665       0.65
# 10   10.0000      0.665       0.65
# 11   20.0000      0.665       0.65
# 12   50.0000      0.665       0.65
# 13  100.0000      0.665       0.65
# 14  250.0000      0.665       0.65
# 15  500.0000      0.665       0.65

# %%
"""
=== PART 6.1.3: Effect of Activation Functions ===

REQUESTED:
* "Tabular form" for data that shows the effect of hyperparameters on accuracy.
* Hyper parameter: ACTIVATION FUNCTION
* Must "select and report reasonable values for other parameters.

EXECUTION: 
* We select values of ACTIVATION FUNCTION \in {Linear, ReLU, Sigmoid}
* Reasonable other values:
    * epochs:       500
    * alpha:        0.05
    * random seed:  201
"""

epochs = 500
alpha = 0.05
random_seed = 201

activation_functions = ['Linear', 'ReLU', 'Sigmoid']
# Storing 'effects on training and validation accuracy'.
training_accuracies = []
validation_accuracies = []

report = get_report(linear, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=False, mute=True)
training_accuracies.append(report['final training accuracy'])
validation_accuracies.append(report['final validation accuracy'])

report = get_report(ReLU, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=False, mute=True)
training_accuracies.append(report['final training accuracy'])
validation_accuracies.append(report['final validation accuracy'])

report = get_report(sigmoid, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=False, mute=True)
training_accuracies.append(report['final training accuracy'])
validation_accuracies.append(report['final validation accuracy'])

print("=== EFFECT OF LEARNING RATE ON TRAINING AND VALIDATION ACCURACY ===")
# print("Activation Functions: \t{}".format(activation_functions))
# print("Training Accuracies: \t{}".format(training_accuracies))
# print("Validation Accuracies: \t{}".format(validation_accuracies))

d = {'Activation Func': activation_functions, 'Train Acc': training_accuracies, 'Valid Acc': validation_accuracies}
df = pd.DataFrame(data=d)
df
# Out:
# === EFFECT OF LEARNING RATE ON TRAINING AND VALIDATION ACCURACY ===
#   Activation Func  Train Acc  Valid Acc
# 0          Linear      0.970       0.90
# 1            ReLU      0.990       1.00
# 2         Sigmoid      0.975       0.95

# %%
"""
=== PART 6.1.4: Effect of 5 Random Seeds ===

REQUESTED:
* "Tabular form" for data that shows the effect of hyperparameters on accuracy.
* Hyper parameter: RANDOM SEED
* Must "select and report reasonable values for other parameters.

EXECUTION: 
* We select values of `random_seed` = [0, 4, 2, 3, 9]
* Reasonable other values:
    * epochs:           250
    * activ. func.:     ReLU
    * alpha:            0.005
"""

epochs = 250
alpha = 0.005
random_seeds = [0, 4, 2, 3, 9]

# Storing 'effects on training and validation accuracy'.
training_accuracies = []
validation_accuracies = []

for random_seed in random_seeds:
    report = get_report(ReLU, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=False, mute=True)

    training_accuracies.append(report['final training accuracy'])
    validation_accuracies.append(report['final validation accuracy'])

print("=== EFFECT OF RANDOM SEED ON TRAINING AND VALIDATION ACCURACY ===")
# print("Random Seed: \t\t{}".format(random_seeds))
# print("Training Accuracies: \t{}".format(training_accuracies))
# print("Validation Accuracies: \t{}".format(validation_accuracies))

d = {'Rand Seed': random_seeds, 'Train Acc': training_accuracies, 'Valid Acc': validation_accuracies}
df = pd.DataFrame(data=d)
df
# Out:
# === EFFECT OF RANDOM SEED ON TRAINING AND VALIDATION ACCURACY ===
#    Rand Seed  Train Acc  Valid Acc
# 0          0      0.890       0.85
# 1          4      0.925       0.80
# 2          2      0.905       0.95
# 3          3      0.860       0.85
# 4          9      0.950       0.90

# %%
"""
=== PART 6.1.5: Best Possible Results in Fewest Epochs ===

REQUESTED:
* "Tabular form" for data that shows the effect of hyperparameters on accuracy.
* Hyper parameter: RANDOM SEED
* Must "select and report reasonable values for other parameters.

EXECUTION: 
* We select values of random_seed = [0, 4, 2, 3, 9
* Reasonable other values:
    * epochs:           75
    * activ. func.:     ReLU
    * alpha:            0.05
    * random_seed:      180
"""

epochs = 20
alpha = 0.05
random_seed = 180

# Storing 'effects on training and validation accuracy'.
training_accuracies = []
validation_accuracies = []

report = get_report(ReLU, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=True, mute=False)

print("Parameters: Weights = {}".format(report['model'].weights))
print("Parameters: Bias = {}".format(report['model'].bias))

dispKernel(report['model'].weights, 3, 12)
# Out:
# Activation Function: 	ReLU
# Learning Rate: 		0.05
# Number of Epochs: 	20
# Random Seed: 		180
# ...
# Final Training Accuracy: 	0.955
# Final Validation Accuracy: 	1.0
# Final Training Loss (avg): 	0.07115583418703729
# Final Validation Loss (avg): 	0.04900431083861176
# Parameters: Weights = [ 0.11070601 -0.21661655  0.17559251 -0.11500243  0.36745238  0.08907574
#  -0.0258889  -0.24192523  0.25366264]
# Parameters: Bias = -0.15218629422247648

# %%
"""
=== PART 6.2.1: Learning Rate is Too Low! ===

REQUESTED:
* __Properly labelled__ loss and accuracy plots vs. epoch.
* Nine weights displayed via `dispKernel` function.

EXECUTION: 
* We select alpha:      0.001
* Reasonable other values:
    * epochs:           250
    * activ. func.:     ReLU
    * random_seed:      191
"""

epochs = 250
alpha = 0.001
random_seed = 191

# Storing 'effects on training and validation accuracy'.

report = get_report(ReLU, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=True, mute=False)

dispKernel(report['model'].weights, 3, 12)
# Out:
# Activation Function: 	ReLU
# Learning Rate: 		0.001
# Number of Epochs: 	250
# Random Seed: 		191
# ...
# Final Training Accuracy: 	0.51
# Final Validation Accuracy: 	0.65
# Final Training Loss (avg): 	0.6385017247671487
# Final Validation Loss (avg): 	0.6190566322665776

# %%
"""
=== PART 6.2.2: Learning Rate is Too High! ===

REQUESTED:
* __Properly labelled__ loss and accuracy plots vs. epoch.
* Nine weights displayed via `dispKernel` function.

EXECUTION: 
* We select alpha:      10
* Reasonable other values:
    * epochs:           250
    * activ. func.:     ReLU
    * random_seed:      194
"""

epochs = 250
alpha = .15
random_seed = 194

# Storing 'effects on training and validation accuracy'.

report = get_report(ReLU, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=True, mute=False)
dispKernel(report['model'].weights, 3, 12)
# Out:
# Activation Function: 	ReLU
# Learning Rate: 		0.15
# Number of Epochs: 	250
# Random Seed: 		194
# ...
# Final Training Accuracy: 	0.665
# Final Validation Accuracy: 	0.65
# Final Training Loss (avg): 	0.3350002232205514
# Final Validation Loss (avg): 	0.35

# %%
"""
=== PART 6.2.3: Learning Rate is Just Right! ===

REQUESTED:
* __Properly labelled__ loss and accuracy plots vs. epoch.
* Nine weights displayed via `dispKernel` function.

EXECUTION: 
* We select alpha:      0.05
* Reasonable other values:
    * epochs:           250
    * activ. func.:     ReLU
    * random_seed:      194
"""

epochs = 250
alpha = 0.05
random_seed = 100

# Storing 'effects on training and validation accuracy'.
training_accuracies = []
validation_accuracies = []

report = get_report(ReLU, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=True, mute=False)

dispKernel(report['model'].weights, 3, 12)
# Out:
# Activation Function: 	ReLU
# Learning Rate: 		0.05
# Number of Epochs: 	250
# Random Seed: 		100
# ...
# Final Training Accuracy: 	0.985
# Final Validation Accuracy: 	1.0
# Final Training Loss (avg): 	0.01214694664125074
# Final Validation Loss (avg): 	0.024843129918858668

# %%
"""
=== PART 6.2.3: Plots for each of the three activation functions. ===

REQUESTED:
* __Properly labelled__ loss and accuracy plots vs. epoch.
* Nine weights displayed via `dispKernel` function.

EXECUTION: 
* We select alpha:      0.05
* Reasonable other values:
    * epochs:           250
    * activ. func.:     ReLU
    * random_seed:      194
"""

epochs = 500
alpha = 0.1
random_seed = 23

# Storing 'effects on training and validation accuracy'.
training_accuracies = []
validation_accuracies = []

report = get_report(sigmoid, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=True, mute=False)
dispKernel(report['model'].weights, 3, 12)
report = get_report(ReLU, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=True, mute=False)
dispKernel(report['model'].weights, 3, 12)
report = get_report(linear, num_epochs=epochs, alpha=alpha, rand_seed=random_seed, plot=True, mute=False)
dispKernel(report['model'].weights, 3, 12)
# Out:
# Activation Function: 	Sigmoid
# Learning Rate: 		0.1
# Number of Epochs: 	500
# Random Seed: 		23
# ...
# Final Training Accuracy: 	0.985
# Final Validation Accuracy: 	0.95
# Final Training Loss (avg): 	0.04909988204611978
# Final Validation Loss (avg): 	0.06807577527881666
# Activation Function: 	ReLU
# Learning Rate: 		0.1
# Number of Epochs: 	500
# Random Seed: 		23
# ...
# Final Training Accuracy: 	0.99
# Final Validation Accuracy: 	1.0
# Final Training Loss (avg): 	0.004589387106594914
# Final Validation Loss (avg): 	0.01058630527775861
# Activation Function: 	Linear
# Learning Rate: 		0.1
# Number of Epochs: 	500
# Random Seed: 		23
# ...
# Final Training Accuracy: 	0.97
# Final Validation Accuracy: 	0.9
# Final Training Loss (avg): 	0.05562814639898504
# Final Validation Loss (avg): 	0.06089841871042249
